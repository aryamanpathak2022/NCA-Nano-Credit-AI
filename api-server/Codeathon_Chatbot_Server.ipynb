# %%
pip install flask openai pyngrok

# %%
from flask import Flask, request, jsonify
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from pyngrok import ngrok

app = Flask(__name__)

# Set your Gemini API Key here
GEMINI_API_KEY = "AIzaSyCgJp_2CwgznkIO_58XbYF7D54oAl9Uv98"

# Set ngrok authentication token
ngrok.set_auth_token("2p6lhQoSh8H5WSPgknv9vZ7v7vY_3u8ps8xZMbiNps8tcUWp4")

# Sample chatbot logic using Google's Gemini API
def finance_chatbot(prompt):
    try:
        # Initialize the ChatGoogleGenerativeAI with the Gemini model and API key
        llm = ChatGoogleGenerativeAI(
            api_key=GEMINI_API_KEY,
            model="gemini-1.5-pro",
            temperature=0,
            max_tokens=None,
            timeout=None,
            max_retries=2
        )
        prompt1 = f"""
        I am a business owner/professional in the field of {prompt}. Please provide tailored advice and strategies for the following:

        1. **Business Expansion**: How can I scale my business effectively within my industry, considering current market trends, customer needs, and innovative opportunities? Include specific recommendations for revenue growth, cost management, and competitive differentiation.

        2. **Loan Repayment Strategies**: What are the best approaches to manage and repay loans efficiently for my business? Focus on cash flow optimization, refinancing opportunities, and strategies to improve creditworthiness and financial stability.

        Provide detailed, actionable suggestions that are relevant to my field and adaptable for businesses of my size and stage.
        """
        # Generate the response using the prompt
        response = llm.invoke(prompt1)  # Use the correct method to invoke the model
        # answer = response['choices'][0]['message']['content']
        return response.content
    except Exception as e:
        return f"An error occurred: {str(e)}"

@app.route("/chat", methods=["POST"])
def chat():
    user_input = request.json.get("query", "")
    if not user_input:
        return jsonify({"error": "No input provided"}), 400

    # Generate response from chatbot
    bot_response = finance_chatbot(user_input)
    print(bot_response)
    return jsonify({"response": bot_response})

if __name__ == "__main__":
    # Open a tunnel to the localhost server
    public_url = ngrok.connect(5000)
    print(f" * ngrok tunnel \"{public_url}\" -> http://127.0.0.1:5000")

    # Run Flask app
    app.run(host="0.0.0.0", port=5000)

# %%
from flask import Flask, request, jsonify
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from pyngrok import ngrok

app = Flask(__name__)

# Set your Gemini API Key here
GEMINI_API_KEY = "AIzaSyCgJp_2CwgznkIO_58XbYF7D54oAl9Uv98"

# Set ngrok authentication token
ngrok.set_auth_token("2p6lhQoSh8H5WSPgknv9vZ7v7vY_3u8ps8xZMbiNps8tcUWp4")

# Sample chatbot logic using Google's Gemini API
def survey_chatbot(prompt):
    try:
        # Initialize the ChatGoogleGenerativeAI with the Gemini model and API key
        llm = ChatGoogleGenerativeAI(
            api_key=GEMINI_API_KEY,
            model="gemini-1.5-pro",
            temperature=0,
            max_tokens=None,
            timeout=None,
            max_retries=2
        )
        prompt1 = generate_survey_questions(prompt)
        # Generate the response using the prompt
        response = llm.invoke(prompt1)  # Use the correct method to invoke the model
        # answer = response['choices'][0]['message']['content']
        return response.content
    except Exception as e:
        return f"An error occurred: {str(e)}"


def generate_survey_questions(user_profession):
    prompt = f"""
    I am conducting a survey to assess individuals in the field of {user_profession}. The survey is designed to predict the following attributes:

    1. Community Reputation
    2. Business Activity Observations
    3. Informal Credit Relationships
    4. Asset Ownership
    5. Utility and Bill Payment Patterns
    6. Local Market Standing
    7. Participation in Welfare or Support Programs
    8. Family and Dependents
    9. Seasonal and Environmental Impact
    10. Behavioral Indicators
    11. Business Location and Infrastructure
    12. Customer and Supplier Relationships
    13. Observed Consistency
    14. Training and Skill Development
    15. Debt and Liabilities
    16. Savings and Insurance
    17. Aadhaar Card
    18. Ration Card
    19. Voter ID Card

    Generate 15-20 survey questions that are concise and relevant to predict these attributes. Ensure each question captures essential data for prediction. Provide the questions in a structured list format.
    """
    return prompt



def predict_columns_from_responses(user_profession, survey_responses):
    try:
        # Generate the prompt for prediction
        prompt = f"""
        I have collected survey data for an individual in the field of {user_profession}. Based on the provided survey responses, predict the values for the following attributes.

        Here is the list of attributes with their possible values:

        1. **Community Reputation**: Choose from ["Excellent", "Good", "Average", "Poor", "Unknown"].
        2. **Business Activity Observations**: Provide a number representing the average daily customers (e.g., between 5 and 500).
        3. **Informal Credit Relationships**: Choose from ["Good Credit History", "Has Defaults", "Unknown"].
        4. **Asset Ownership**: Choose from ["Sewing Machine", "Livestock", "Vehicle", "Shop Equipment", "None", "Multiple Assets"].
        5. **Utility and Bill Payment Patterns**: Choose from ["On Time", "Delayed Payments", "No Records", "Partially Paid"].
        6. **Local Market Standing**: Choose from ["Highly Popular", "Moderately Popular", "Average", "Low Footfall", "New Business"].
        7. **Participation in Welfare or Support Programs**: Choose from ["Enrolled in MUDRA", "Enrolled in SHG", "None", "Multiple Programs"].
        8. **Family and Dependents**: Provide a number representing the total family members or dependents (e.g., between 1 and 10).
        9. **Seasonal and Environmental Impact**: Choose from ["High Seasonal Variation", "Moderate Seasonal Variation", "Minimal Seasonal Variation", "Weather Sensitive"].
        10. **Behavioral Indicators**: Choose from ["High Risk-Taker", "Cautious", "Good Problem-Solver", "Indecisive"].
        11. **Business Location and Infrastructure**: Choose from ["Prime Location", "Moderate Traffic", "Low Traffic Area", "Home-Based", "Remote Area"].
        12. **Customer and Supplier Relationships**: Provide a number representing the number of regular connections (e.g., between 1 and 50).
        13. **Observed Consistency**: Choose from ["Regularly Open", "Irregular Operations"].
        14. **Training and Skill Development**: Choose from ["Completed Skill Training", "Ongoing Training", "No Formal Training", "Multiple Certifications"].
        15. **Debt and Liabilities**: Provide a monetary value in INR (e.g., between 1000 and 50000).
        16. **Savings and Insurance**: Choose from ["Chit Fund Savings", "Insurance Policy", "None", "Both Savings and Insurance"].
        17. **Aadhaar Card**: Choose from ["Verified", "Not Verified"].
        18. **Ration Card**: Choose from ["BPL", "APL", "Antyodaya", "Not Provided"].
        19. **Voter ID Card**: Choose from ["Verified", "Not Verified"].

        Survey responses:
        {survey_responses}

        Based on these responses, predict the values for each attribute. Ensure the predictions align with the given value ranges and select the best feasible answer based on the provided data. Respond in the following format:

        - Community Reputation: <Predicted Value>
        - Business Activity Observations: <Predicted Value>
        - Informal Credit Relationships: <Predicted Value>
        - Asset Ownership: <Predicted Value>
        - Utility and Bill Payment Patterns: <Predicted Value>
        - Local Market Standing: <Predicted Value>
        - Participation in Welfare or Support Programs: <Predicted Value>
        - Family and Dependents: <Predicted Value>
        - Seasonal and Environmental Impact: <Predicted Value>
        - Behavioral Indicators: <Predicted Value>
        - Business Location and Infrastructure: <Predicted Value>
        - Customer and Supplier Relationships: <Predicted Value>
        - Observed Consistency: <Predicted Value>
        - Training and Skill Development: <Predicted Value>
        - Debt and Liabilities: <Predicted Value>
        - Savings and Insurance: <Predicted Value>
        - Aadhaar Card: <Predicted Value>
        - Ration Card: <Predicted Value>
        - Voter ID Card: <Predicted Value>
        """

        # Initialize the ChatGoogleGenerativeAI
        llm = ChatGoogleGenerativeAI(
            api_key=GEMINI_API_KEY,
            model="gemini-1.5-pro",
            temperature=0,
            max_tokens=None,
            timeout=None,
            max_retries=2
        )

        # Generate the prediction
        response = llm.invoke(prompt)  # Use the correct method to invoke the model
        return response.content
    except Exception as e:
        return f"An error occurred: {str(e)}"

def collect_responses(gemini_questions):
    """
    Collects survey responses based on the questions generated by Gemini.

    Args:
        gemini_questions (list): A list of questions generated by Gemini.

    Returns:
        dict: A dictionary with {question: response}.
    """
    sample_responses = {}
    gemini_questions = gemini_questions.strip().split("\n")


    print("Please answer the following survey questions:\n")
    for i, question in enumerate(gemini_questions, start=1):
        print(f"Q{i}: {question}")
        response = input("Your answer: ")
        sample_responses[question] = response.strip()  # Store the question and user's response

    return sample_responses


@app.route("/survey", methods=["POST"])
def chat():
    user_input = request.json.get("query", "")
    if not user_input:
        return jsonify({"error": "No input provided"}), 400

    # Generate response from chatbot
    bot_response = survey_chatbot(user_input)
    print(bot_response)






# Example Usage

    # Replace this with Gemini's generated questions
    # gemini_questions = [
    #     "How would your customers describe your reputation in the community?",
    #     "What is the average number of customers you serve daily?",
    #     "Have you borrowed money from informal lenders?",
    #     "How consistent are you in paying your utility bills?",
    #     "How many regular suppliers do you have?",
    #     "What kind of assets do you own for your business operations?",
    #     "Are you enrolled in any welfare or government programs?",
    #     "How many dependents are there in your family?",
    #     "Does your business face seasonal impacts on sales?",
    #     "How would you describe your decision-making behavior?",
    #     "Where is your business located?",
    #     "How consistent are your business hours?",
    #     "Have you undergone any formal training for your business?",
    #     "What is your current total outstanding debt (in INR)?",
    #     "Do you have any savings or insurance policies?",
    #     "Is your Aadhaar Card verified?",
    #     "What type of ration card do you possess?",
    #     "Is your Voter ID verified?"
    # ]
    gemini_questions = bot_response
    # Generate sample responses interactively
    sample_responses = collect_responses(gemini_questions)

    # Print the collected responses
    print("\nCollected Survey Responses:")
    for question, response in sample_responses.items():
        print(f"{question}: {response}")


    return jsonify({"response": bot_response})

# @app.route("/chat", methods=["POST"])
# def chat():
#     user_input = request.json.get("query", "")
#     if not user_input:
#         return jsonify({"error": "No input provided"}), 400

#     # Generate response from chatbot
#     bot_response = finance_chatbot(user_input)
#     print(bot_response)
#     return jsonify({"response": bot_response})

if __name__ == "__main__":
    # Open a tunnel to the localhost server
    public_url = ngrok.connect(5000)
    print(f" * ngrok tunnel \"{public_url}\" -> http://127.0.0.1:5000")

    # Run Flask app
    app.run(host="0.0.0.0", port=5000)
